# %%
# !pip install ultralytics -q
from ultralytics import YOLO
import zipfile
import os
# Out:
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO

# Load your custom model
model = YOLO(r"C:\Users\User\yolo11s.pt")  # Make sure path is correct

# Train on your Open Images YOLO-formatted dataset
model.train(
    data=r"C:\Users\User\open_images_yolo\dataset.yaml",  # Path to YAML
    epochs=50,         # adjust as needed
    imgsz=640,         # or lower like 416
    device="cpu"  # or 'cuda' if using GPU
)
# Out:
# Ultralytics 8.3.141  Python-3.12.0 torch-2.7.0+cpu CPU (11th Gen Intel Core(TM) i7-1165G7 2.80GHz)
# ...

# %%
# import os

# def clean_labels(label_dir, max_class_id=18):
#     removed = 0
#     bad_files = []
    
#     for file in os.listdir(label_dir):
#         if file.endswith(".txt"):
#             full_path = os.path.join(label_dir, file)
#             with open(full_path, "r") as f:
#                 lines = f.readlines()

#             new_lines = []
#             for line in lines:
#                 try:
#                     class_id = int(line.split()[0])
#                     if 0 <= class_id <= max_class_id:
#                         new_lines.append(line)
#                     else:
#                         removed += 1
#                         bad_files.append((file, class_id))
#                 except:
#                     continue

#             with open(full_path, "w") as f:
#                 f.writelines(new_lines)

#     print(f"✅ Cleaned {label_dir} — Removed {removed} lines with invalid class_ids")
#     if bad_files:
#         print("❌ Invalid labels found in:")
#         for fname, bad_id in bad_files:
#             print(f"{fname} → invalid class_id: {bad_id}")

# # Run for both train and val labels
# clean_labels(r"C:\Users\User\open_images_yolo\labels\train")
# clean_labels(r"C:\Users\User\open_images_yolo\labels\val")
